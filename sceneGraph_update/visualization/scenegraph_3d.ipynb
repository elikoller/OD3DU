# %%
import pyviz3d.visualizer as viz
import numpy as np
import math
import open3d as o3d
import pickle

import numpy as np
import pyviz3d.visualizer as viz
# import pyviz3d.src.blender_tools as blt 
import plyfile
import open3d as o3d
import os
from sklearn.neighbors import NearestNeighbors



def read_ply_data(filename):
    filename_in = filename
    file = open(filename_in, 'rb')
    ply_data = plyfile.PlyData.read(file)
    file.close()
    x = ply_data['vertex']['x']
    y = ply_data['vertex']['y']
    z = ply_data['vertex']['z']
    red = ply_data['vertex']['red']
    green = ply_data['vertex']['green']
    blue = ply_data['vertex']['blue']
    object_id = ply_data['vertex']['objectId']
    global_id = ply_data['vertex']['globalId']
    nyu40_id = ply_data['vertex']['NYU40']
    eigen13_id = ply_data['vertex']['Eigen13']
    rio27_id = ply_data['vertex']['RIO27']
 
    vertices = np.empty(len(x), dtype=[('x', 'f4'), ('y', 'f4'), ('z', 'f4'),  ('red', 'u1'), ('green', 'u1'), ('blue', 'u1'),
                                                     ('objectId', 'h'), ('globalId', 'h'), ('NYU40', 'u1'), ('Eigen13', 'u1'), ('RIO27', 'u1')])
    
    vertices['x'] = x.astype('f4')
    vertices['y'] = y.astype('f4')
    vertices['z'] = z.astype('f4')
    vertices['red'] = red.astype('u1')
    vertices['green'] = green.astype('u1')
    vertices['blue'] = blue.astype('u1')
    vertices['objectId'] = object_id.astype('h')
    vertices['globalId'] = global_id.astype('h')
    vertices['NYU40'] = nyu40_id.astype('u1')
    vertices['Eigen13'] = eigen13_id.astype('u1')
    vertices['RIO27'] = rio27_id.astype('u1')
    return vertices
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def generate_ball_pcl(position, radius, color, resolution=5):
    # generate ball
    points = []
    ## generate ball points
    for i in range(0, 360, resolution):
        for j in range(0, 360, resolution):
            x = radius * np.cos(np.deg2rad(i)) * np.sin(np.deg2rad(j))
            y = radius * np.sin(np.deg2rad(i)) * np.sin(np.deg2rad(j))
            z = radius * np.cos(np.deg2rad(j))
            points.append([x, y, z])
    points = np.array(points)
    ## translate ball
    points += position
    colors = np.array([color for _ in range((points.shape[0]))])
    return points, colors

def generate_camera_frustum(vis, cam_extrinsics, target_scene_center = np.array([0, 0, 0]),
                            cam_color = [0, 0, 0],
                            img_width_m = 0.7, cam_depth_range = 0.8, 
                            point_size = 0.04, img_size = (540, 960)):
    image_h = img_size[1]
    image_w = img_size[0]
    img_height_m = img_width_m * image_h / image_w
    
    # get points in camera frustum
    image_center = np.array([0, 0, 0])
    image_corners =  np.array([
        [img_width_m/2.0, img_height_m/2.0, cam_depth_range],
        [-img_width_m/2.0, img_height_m/2.0, cam_depth_range],
        [-img_width_m/2.0, -img_height_m/2.0, cam_depth_range],
        [img_width_m/2.0, -img_height_m/2.0, cam_depth_range],
    ])
    T_rescan2ref_right, T_camera2rescan = cam_extrinsics[0], cam_extrinsics[1]
    # transform to world coord
    image_center =  image_center @ (T_camera2rescan[:3, :3]).T  + T_camera2rescan[:3, 3].T
    image_corners = image_corners @ (T_camera2rescan[:3, :3]).T  + T_camera2rescan[:3, 3].T
    image_center =  image_center @ T_rescan2ref_right[:3, :3]  + T_rescan2ref_right[3, :3]
    image_corners = image_corners @ T_rescan2ref_right[:3, :3]  + T_rescan2ref_right[3, :3]
    image_center = image_center + target_scene_center.reshape(1, 3)
    image_corners = image_corners + target_scene_center.reshape(1, 3)
    # get lines in camera frustum
    line_ps_start = []
    line_ps_end = []
    black_color = np.array([0.0, 0.0, 0.0])
    vis.add_points('img_center', image_center.reshape(-1, 3), black_color.reshape(-1, 3), point_size=100, resolution=15, visible=True)    
    for i in range(4):
        # line_ps_start.append(image_center.reshape(3))
        # line_ps_end.append(image_corners[i].reshape(3))
        edges = []
        edges.append(image_center.reshape(3))
        edges.append(image_corners[i].reshape(3))
        # obj = cylinder_between(x1, y1, z1, x2, y2, z2, properties['edge_width'] * 2, properties['color'])
        # create_mat(obj)
        vis.add_polyline(f'img_center_corner{i}', np.array(edges), color=np.array([0, 0, 0]), edge_width=0.015)
        vis.add_points(f'corner{i}', image_center.reshape(-1,3), black_color.reshape(-1, 3), point_size=25, resolution=15, visible=True)    
    for i in range(4):
        # line_ps_start.append(image_corners[i].reshape(3))
        # line_ps_end.append(image_corners[(i+1)%4].reshape(3))
        edges = []
        edges.append(image_corners[i].reshape(3))
        edges.append(image_corners[(i+1)%4].reshape(3))
        vis.add_polyline(f'center{[i]}_corner{i+1}', np.array(edges), color=np.array([0, 0, 0]), edge_width=0.015)
    # line_ps_start = np.array(line_ps_start)
    # line_ps_end = np.array(line_ps_end)
    # # generate point balls
    # points_center, colors_center = generate_ball_pcl(image_center, point_size, cam_color)
   

def save_visualize(data_dir, scan_id,mesh_file, out_folder, img_pose = None, img_size = (540, 960), 
                   node_size = 200, matched_node_size = 700, matched_ids = np.array([]),
                   render_cam_pose = [-0.265198, -0.411423, 7.11054],
                   render_cam_look = [0.0, 0.0, 0.0], obj_count_th = 1000,
                   blender_path = None):
    scene = o3d.io.read_point_cloud(mesh_file)

    scene_meta = read_ply_data(mesh_file)

    scene.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))

    point_normals = np.asarray(scene.normals)
    point_positions = np.asarray(scene.points)
    points_center = np.mean(point_positions, axis=0)
    point_positions -= points_center
    point_colors = np.asarray(scene.colors)
    point_colors = point_colors[:, [2, 1, 0]]
    objectIds = scene_meta['objectId']
    
    # filter out points with color (0, 0, 0)
    mask = np.any(point_colors > 0, axis=1)
    point_positions = point_positions[mask]
    point_normals = point_normals[mask]
    point_colors = point_colors[mask]
    objectIds = objectIds[mask]
    ## filter out points with number of points less than 100
    unique_objectIds, counts = np.unique(objectIds, return_counts=True)
    mask = np.isin(objectIds, unique_objectIds[counts > obj_count_th])
    point_positions = point_positions[mask]
    point_normals = point_normals[mask]
    point_colors = point_colors[mask]
    objectIds = objectIds[mask]
    
    print("point_positions.shape", point_positions.shape)
    print("point_normals.shape", point_normals.shape)
    print("point_colors.shape", point_colors.shape)
    print("objectIds.shape", objectIds.shape)

    # Find instance centers and colors
    
    unique_objectIds = np.unique(objectIds)
    obj_centers = []
    obj_colors = []
    obj_ids = []
    for obj_id in unique_objectIds:
        obj_points = point_positions[objectIds == obj_id]
        obj_center = np.mean(obj_points, axis=0)
        obj_color = point_colors[objectIds == obj_id][0, :]
        
        obj_positions_relative = obj_points - obj_center
        dist_norm = np.linalg.norm(obj_positions_relative, axis=1)
        nearest_idx = np.argsort(dist_norm)[0]
        obj_patch_pos = obj_points[nearest_idx]
        obj_center = obj_patch_pos
        
        obj_centers.append(obj_center)
        obj_colors.append(obj_color)
        obj_ids.append(obj_id)
    obj_centers = np.concatenate(obj_centers).reshape(-1, 3)
    obj_colors = np.concatenate(obj_colors).reshape(-1, 3)
    mask = obj_centers[:, 2] < 0.8
    obj_centers = obj_centers[mask]
    obj_colors = obj_colors[mask]
    obj_ids = np.array(obj_ids)[mask]
    
    vis_nodes = viz.Visualizer(position=render_cam_pose, look_at =  render_cam_look, focal_length=28)
    vis_pcs = viz.Visualizer(position=render_cam_pose, look_at =  render_cam_look, focal_length=28)
    vis_pcs_nodes = viz.Visualizer(position=render_cam_pose, look_at =  render_cam_look, focal_length=28)
    pcs_mask = point_positions[:,2] < 0.8
    for idx, obj_id in enumerate(obj_ids):
        obj_center = obj_centers[idx]
        obj_color = obj_colors[idx]
        obj_size = node_size if obj_id not in matched_ids else matched_node_size

        vis_nodes.add_points('obj_{}'.format(obj_id), obj_center.reshape(-1,3), 
                            obj_color.reshape(-1,3) * 255, point_size=obj_size, resolution=15, visible=True)  
        vis_pcs_nodes.add_points('obj_{}'.format(obj_id), obj_center.reshape(-1,3), 
                            obj_color.reshape(-1,3) * 255, point_size=obj_size, resolution=15, visible=True)  

        obj_mask = np.logical_and( objectIds == obj_id, pcs_mask)
        
        if len(matched_ids) == 0:
            alpha = 1.0
            vis_pcs.add_points('pcs_obj_{}'.format(obj_id), point_positions[obj_mask], point_colors[obj_mask] * 255, point_normals[obj_mask], 
                point_size=50, visible=True, alpha=alpha)
        else:
            alpha = 0.1 if obj_id not in matched_ids else 1.0
            vis_pcs.add_points('pcs_obj_{}'.format(obj_id), point_positions[obj_mask], point_colors[obj_mask] * 255, point_normals[obj_mask], 
                point_size=50, visible=True, alpha=alpha)
            
        vis_pcs_nodes.add_points('pcs_obj_{}'.format(obj_id), point_positions[obj_mask], point_colors[obj_mask] * 255, point_normals[obj_mask], 
            point_size=50, visible=True, alpha=0.7)
                
    # nbrs = NearestNeighbors(n_neighbors=5, algorithm='ball_tree').fit(obj_centers)
    # distances, indices = nbrs.kneighbors(obj_centers)
    # for i in range(indices.shape[0]):
    #     for jj, j in enumerate(indices[i].tolist()):
    #         if distances[i][jj] < 2.0 and distances[i][jj] > 0.001:
    #             edges = []
    #             edges.append(obj_centers[i])
    #             edges.append(obj_centers[j])
    #             print("edges", edges)
    #             vis_nodes.add_polyline(f'polyline{i}{j}', np.array(edges), color=np.array([250.0, 250.0, 250.0]), edge_width=0.02)
    #             vis_pcs_nodes.add_polyline(f'polyline{i}{j}', np.array(edges), color=np.array([250.0, 250.0, 250.0]), edge_width=0.02)

    path = os.path.join(data_dir, "files/orig/data/" "{}.pkl".format(scan_id))
    with open(path, 'rb') as file:
        data = pickle.load(file)

    edges = data["edges"]
    obj2idx = data["object_id2idx"]
    all_objs= data["objects_id"]
    print("all obj id with the smalles ones", len(all_objs))
    print
    #reverse the mapping to get idx -> obj_id
    idx2obj = {v: k for k, v in obj2idx.items()}

   
    print( "edges length", len(edges), " with elements", edges)

    print("object center length", len(obj_centers) ,"with elements" , obj_centers)
    print("object ids length", len(obj_ids) ,"with elements" , obj_ids)
    for edge in edges:
        i = edge[0] #idx i of the first object  overall index
        j = edge[1] #idx j of the second object

        i_obj_id = idx2obj[i] #object id
        j_obj_id = idx2obj[j] #object id

        if ( i_obj_id in obj_ids and j_obj_id in obj_ids):

            #local idx of obj_id in obj_id without the smalles ones
            i_idx = np.where(obj_ids == i_obj_id)[0]
            j_idx = np.where(obj_ids == j_obj_id)[0]

            coord_i = obj_centers[i_idx] #need to access with the idx within obj id
            coord_j = obj_centers[j_idx]

            square_diff = (np.array(coord_i) - np.array(coord_j))**2
            distance = np.sqrt(np.sum(square_diff))

            if distance < 2.0 and distance> 0.001:
            
                # Add the edge to the list
                ed = []
                ed.append(coord_i[0])
                ed.append(coord_j[0])
                # print("ed", ed)
                
                # Add polyline to vis_nodes
                vis_nodes.add_polyline(f'polyline{i}{j}', np.array(ed), color=np.array([250.0, 250.0, 250.0]), alpha = 0.5,edge_width=0.02)
                
                # Add polyline to vis_pcs_nodes if needed (assuming it has similar add_polyline method)
                vis_pcs_nodes.add_polyline(f'polyline{i}{j}', np.array(ed), color=np.array([250.0, 250.0, 250.0]), alpha = 0.5,edge_width=0.02)

      

    
    if img_pose is not None:
        # line_ps_start, line_ps_end, points_frustum, colors_frustum = \
        #     generate_camera_frustum(img_pose, img_size=img_size, img_width_m=0.4)
        # # add image frustum
        # vis_pcs.add_points(
        #     'frustum', 
        #     positions=points_frustum,
        #     colors=colors_frustum)
        # vis_pcs.add_lines(
        #     'frustum_lines', 
        #     line_ps_start, line_ps_end)
        generate_camera_frustum( vis_pcs, img_pose, img_size=img_size, img_width_m=0.6, cam_depth_range=0.4, target_scene_center=-points_center)

        # When we added everything we need to the visualizer, we save it.
    out_folder_pcs = os.path.join(out_folder, "pcs")
    out_folder_nodes = os.path.join(out_folder, "nodes")
    out_folder_pcs_nodes = os.path.join(out_folder, "pcs_nodes")

    #make sure the directories exist
    for dir_path in [out_folder_pcs, out_folder_nodes, out_folder_pcs_nodes]:
        try:
            os.makedirs(dir_path, exist_ok=True)
            
        except Exception as e:
            print(f"Failed to create directory {dir_path}: {e}")

    blender_args = {
    "executable_path": blender_path,
    "output_prefix" : False
    }
            
    vis_pcs.save(path =out_folder_pcs, port= 8080,blender_args= blender_args, verbose= True)
    vis_nodes.save(path = out_folder_nodes, port= 8080, blender_args= blender_args, verbose= True )
    vis_pcs_nodes.save(path = out_folder_pcs_nodes, port= 8080,blender_args= blender_args, verbose= True)
        
  
    # return {
    #     'img_pose': img_pose,
    #     'line_ps_start': line_ps_start,
    #     'line_ps_end': line_ps_end,
    #     'points_frustum': points_frustum,
    #     'colors_frustum': colors_frustum,
        
    # }

# %%
# 20c993b3-698f-29c5-859c-dca8ddecf220
scan_id = "8eabc426-5af7-2f32-87bb-a16609b099e3" #"422885ab-192d-25fc-8448-e7f34c7b5eea"

mesh_file = os.path.join('/local/home/ekoller/R3Scan/scenes', scan_id, "labels.instances.align.annotated.v2.ply")
data_dir = "/local/home/ekoller/R3Scan"
out_folder = os.path.join("/local/home/ekoller/visscenegraph",scan_id)
blender_path = "/local/home/ekoller/visscenegraph/blender-4.1.1-linux-x64/blender"
save_visualize(data_dir, scan_id,mesh_file, out_folder, img_size=(960, 540), 
               node_size=300, matched_node_size=500,
               render_cam_pose = [-0.5, -2.5, 2.8], render_cam_look = [0.0, 0.0, -0.3], obj_count_th=100, blender_path=blender_path)
# Out:
# point_positions.shape (63001, 3)
# point_normals.shape (63001, 3)
# point_colors.shape (63001, 3)
# objectIds.shape (63001,)
# all obj id with the smalles ones 33
# edges length 1056  with elements [[ 1  0]
#  [ 2  0]
#  [ 3  2]
#  ...
#  [32 29]
#  [32 30]
#  [32 31]]
# object center length 25 with elements [[-0.0954162  -0.18118452 -1.07650097]
#  [ 1.0717678   1.27881548  0.39243903]
#  [ 1.4245838  -2.21366152  0.41243903]
#  [ 1.7914338  -1.92118452 -0.18756097]
#  [ 2.2761238  -0.96118452  0.05243903]
#  [-0.9784762  -0.90118452  0.25243903]
#  [-1.1642862   2.03881548  0.47243903]
#  [-1.7754162   1.73718548  0.53243903]
#  [-1.7154162   1.29881548 -0.53697097]
#  [-1.8554162   0.49881548 -0.92664097]
#  [-1.2484262   0.97881548 -0.40756097]
#  [-0.3554162   1.03881548 -0.54444097]
#  [ 0.5245838   0.56574548 -0.88756097]
#  [ 0.8445838  -2.47107652 -0.12756097]
#  [ 1.8352238  -0.14118452 -0.74756097]
#  [ 1.8245838  -0.28118452 -0.28563797]
#  [ 1.5245838  -1.97570982  0.49243903]
#  [ 1.4566838  -2.06118452  0.11243903]
#  [ 1.7386238  -1.84118452  0.23243903]
#  [-2.1154162   0.99881548 -0.17230597]
#  [-0.1372562   2.51881548 -0.22756097]
#  [-0.4154162   2.32665548 -0.36756097]
#  [-0.4354162   2.19881548 -0.43795797]
#  [-0.0554162   1.55881548 -0.50828097]
#  [-1.3354162   1.51881548  0.20918803]]
# object ids length 25 with elements [ 1  2  4  5  6  7  8  9 11 12 13 14 15 16 18 19 26 27 28 29 32 33 34 35
#  36]
#
# ************************************************************************
# 1) Start local server:
#     cd /local/home/ekoller/visscenegraph/8eabc426-5af7-2f32-87bb-a16609b099e3/pcs; python -m http.server 8080
# 2) Open in browser:
#     http://localhost:8080
# ************************************************************************
# Blender 4.1.1 (hash e1743a0317bc built 2024-04-15 23:47:45)
# <bpy_struct, Object("Cube") at 0x7f102f53b708>
# <bpy_struct, Object("Light") at 0x7f102f53bc08>
# <bpy_struct, Object("Camera") at 0x7f102f53b208>
# Camera_0 {'type': 'camera', 'position': [-0.5, -2.5, 2.799999952316284], 'look_at': [0.0, 0.0, -0.30000001192092896], 'up': [0.0, 0.0, 1.0], 'focal_length': 28.0, 'animation': False}
# pcs_obj_1 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 6157, 'binary_filename': 'pcs_obj_1.bin'}
# PLY import of 'pcs_obj_1.ply' took 728.56 ms
# pcs_obj_2 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 2579, 'binary_filename': 'pcs_obj_2.bin'}
# PLY import of 'pcs_obj_2.ply' took 57.95 ms
# pcs_obj_4 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 746, 'binary_filename': 'pcs_obj_4.bin'}
# PLY import of 'pcs_obj_4.ply' took 13.65 ms
# pcs_obj_5 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 807, 'binary_filename': 'pcs_obj_5.bin'}
# PLY import of 'pcs_obj_5.ply' took 15.26 ms
# pcs_obj_6 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 3882, 'binary_filename': 'pcs_obj_6.bin'}
# PLY import of 'pcs_obj_6.ply' took 154.61 ms
# pcs_obj_7 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 3976, 'binary_filename': 'pcs_obj_7.bin'}
# PLY import of 'pcs_obj_7.ply' took 98.06 ms
# pcs_obj_8 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 1413, 'binary_filename': 'pcs_obj_8.bin'}
# PLY import of 'pcs_obj_8.ply' took 30.64 ms
# pcs_obj_9 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 1888, 'binary_filename': 'pcs_obj_9.bin'}
# PLY import of 'pcs_obj_9.ply' took 44.45 ms
# pcs_obj_11 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 8075, 'binary_filename': 'pcs_obj_11.bin'}
# PLY import of 'pcs_obj_11.ply' took 520.78 ms
# pcs_obj_12 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 212, 'binary_filename': 'pcs_obj_12.bin'}
# PLY import of 'pcs_obj_12.ply' took 3.96 ms
# pcs_obj_13 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 1623, 'binary_filename': 'pcs_obj_13.bin'}
# PLY import of 'pcs_obj_13.ply' took 218.46 ms
# pcs_obj_14 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 2641, 'binary_filename': 'pcs_obj_14.bin'}
# PLY import of 'pcs_obj_14.ply' took 64.67 ms
# pcs_obj_15 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 549, 'binary_filename': 'pcs_obj_15.bin'}
# PLY import of 'pcs_obj_15.ply' took 10.69 ms
# pcs_obj_16 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 7651, 'binary_filename': 'pcs_obj_16.bin'}
# PLY import of 'pcs_obj_16.ply' took 333.66 ms
# pcs_obj_18 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 444, 'binary_filename': 'pcs_obj_18.bin'}
# PLY import of 'pcs_obj_18.ply' took 10.10 ms
# pcs_obj_19 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 538, 'binary_filename': 'pcs_obj_19.bin'}
# PLY import of 'pcs_obj_19.ply' took 11.43 ms
# pcs_obj_26 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 123, 'binary_filename': 'pcs_obj_26.bin'}
# PLY import of 'pcs_obj_26.ply' took 2.72 ms
# pcs_obj_27 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 165, 'binary_filename': 'pcs_obj_27.bin'}
# PLY import of 'pcs_obj_27.ply' took 3.30 ms
# pcs_obj_28 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 167, 'binary_filename': 'pcs_obj_28.bin'}
# PLY import of 'pcs_obj_28.ply' took 3.18 ms
# pcs_obj_29 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 517, 'binary_filename': 'pcs_obj_29.bin'}
# PLY import of 'pcs_obj_29.ply' took 10.43 ms
# pcs_obj_32 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 372, 'binary_filename': 'pcs_obj_32.bin'}
# PLY import of 'pcs_obj_32.ply' took 6.87 ms
# pcs_obj_33 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 214, 'binary_filename': 'pcs_obj_33.bin'}
# PLY import of 'pcs_obj_33.ply' took 5.26 ms
# pcs_obj_34 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 126, 'binary_filename': 'pcs_obj_34.bin'}
# PLY import of 'pcs_obj_34.ply' took 2.99 ms
# pcs_obj_35 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 1965, 'binary_filename': 'pcs_obj_35.bin'}
# PLY import of 'pcs_obj_35.ply' took 258.61 ms
# pcs_obj_36 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 107, 'binary_filename': 'pcs_obj_36.bin'}
# PLY import of 'pcs_obj_36.ply' took 2.10 ms
# Info: Total files 0 | Changed 0 | Failed 0
# Info: Saved "blender_scene.blend"
# Saved blender file to: /local/home/ekoller/visscenegraph/8eabc426-5af7-2f32-87bb-a16609b099e3/pcs/blender_scene.blend
#
# Blender quit
#
# ************************************************************************
# Blender instructions
# cd /local/home/ekoller/visscenegraph/8eabc426-5af7-2f32-87bb-a16609b099e3/pcs; /local/home/ekoller/visscenegraph/blender-4.1.1-linux-x64/blender --background --python blender_script.py
# ************************************************************************
#
# ************************************************************************
# 1) Start local server:
#     cd /local/home/ekoller/visscenegraph/8eabc426-5af7-2f32-87bb-a16609b099e3/nodes; python -m http.server 8080
# 2) Open in browser:
#     http://localhost:8080
# ************************************************************************
# Blender 4.1.1 (hash e1743a0317bc built 2024-04-15 23:47:45)
# <bpy_struct, Object("Cube") at 0x7f88ed338708>
# <bpy_struct, Object("Light") at 0x7f88ed338c08>
# <bpy_struct, Object("Camera") at 0x7f88ed338208>
# Camera_0 {'type': 'camera', 'position': [-0.5, -2.5, 2.799999952316284], 'look_at': [0.0, 0.0, -0.30000001192092896], 'up': [0.0, 0.0, 1.0], 'focal_length': 28.0, 'animation': False}
# obj_1 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_1.bin'}
# PLY import of 'obj_1.ply' took 0.52 ms
# obj_2 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_2.bin'}
# PLY import of 'obj_2.ply' took 0.52 ms
# obj_4 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_4.bin'}
# PLY import of 'obj_4.ply' took 0.49 ms
# obj_5 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_5.bin'}
# PLY import of 'obj_5.ply' took 0.48 ms
# obj_6 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_6.bin'}
# PLY import of 'obj_6.ply' took 0.46 ms
# obj_7 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_7.bin'}
# PLY import of 'obj_7.ply' took 0.47 ms
# obj_8 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_8.bin'}
# PLY import of 'obj_8.ply' took 0.47 ms
# obj_9 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_9.bin'}
# PLY import of 'obj_9.ply' took 0.45 ms
# obj_11 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_11.bin'}
# PLY import of 'obj_11.ply' took 0.46 ms
# obj_12 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_12.bin'}
# PLY import of 'obj_12.ply' took 0.47 ms
# obj_13 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_13.bin'}
# PLY import of 'obj_13.ply' took 0.52 ms
# obj_14 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_14.bin'}
# PLY import of 'obj_14.ply' took 0.50 ms
# obj_15 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_15.bin'}
# PLY import of 'obj_15.ply' took 0.48 ms
# obj_16 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_16.bin'}
# PLY import of 'obj_16.ply' took 0.48 ms
# obj_18 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_18.bin'}
# PLY import of 'obj_18.ply' took 0.46 ms
# obj_19 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_19.bin'}
# PLY import of 'obj_19.ply' took 0.46 ms
# obj_26 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_26.bin'}
# PLY import of 'obj_26.ply' took 0.48 ms
# obj_27 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_27.bin'}
# PLY import of 'obj_27.ply' took 0.54 ms
# obj_28 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_28.bin'}
# PLY import of 'obj_28.ply' took 0.56 ms
# obj_29 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_29.bin'}
# PLY import of 'obj_29.ply' took 0.50 ms
# obj_32 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_32.bin'}
# PLY import of 'obj_32.ply' took 0.47 ms
# obj_33 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_33.bin'}
# PLY import of 'obj_33.ply' took 0.46 ms
# obj_34 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_34.bin'}
# PLY import of 'obj_34.ply' took 0.48 ms
# obj_35 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_35.bin'}
# PLY import of 'obj_35.ply' took 0.59 ms
# obj_36 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 300, 'num_points': 1, 'binary_filename': 'obj_36.bin'}
# PLY import of 'obj_36.ply' took 0.54 ms
# polyline32 {'type': 'polyline', 'positions': [[1.7914338001211245, -1.921184519283624, -0.18756096681857948], [1.4245838001211246, -2.213661519283624, 0.4124390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline50 {'type': 'polyline', 'positions': [[-0.9784761998788754, -0.9011845192836241, 0.25243903318142047], [-0.09541619987887545, -0.1811845192836241, -1.0765009668185797]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline76 {'type': 'polyline', 'positions': [[-1.7754161998788753, 1.7371854807163758, 0.5324390331814205], [-1.1642861998788754, 2.038815480716376, 0.4724390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline100 {'type': 'polyline', 'positions': [[-1.8554161998788754, 0.49881548071637605, -0.9266409668185794], [-0.09541619987887545, -0.1811845192836241, -1.0765009668185797]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline110 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-0.09541619987887545, -0.1811845192836241, -1.0765009668185797]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline120 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-0.09541619987887545, -0.1811845192836241, -1.0765009668185797]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline130 {'type': 'polyline', 'positions': [[1.0717678001211246, 1.2788154807163759, 0.3924390331814205], [-0.43541619987887553, 2.1988154807163762, -0.43795796681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline160 {'type': 'polyline', 'positions': [[1.8352238001211245, -0.14118451928362408, -0.7475609668185795], [-0.09541619987887545, -0.1811845192836241, -1.0765009668185797]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1716 {'type': 'polyline', 'positions': [[1.8245838001211245, -0.2811845192836242, -0.28563796681857956], [1.8352238001211245, -0.14118451928362408, -0.7475609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline243 {'type': 'polyline', 'positions': [[1.5245838001211245, -1.975709819283624, 0.49243903318142046], [1.7914338001211245, -1.921184519283624, -0.18756096681857948]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline253 {'type': 'polyline', 'positions': [[1.4566838001211246, -2.061184519283624, 0.11243903318142051], [1.7914338001211245, -1.921184519283624, -0.18756096681857948]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline263 {'type': 'polyline', 'positions': [[1.7386238001211245, -1.841184519283624, 0.2324390331814205], [1.7914338001211245, -1.921184519283624, -0.18756096681857948]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline279 {'type': 'polyline', 'positions': [[-2.115416199878876, 0.998815480716376, -0.17230596681857946], [-1.7154161998788753, 1.2988154807163759, -0.5369709668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2831 {'type': 'polyline', 'positions': [[-0.13725619987887544, 2.5188154807163756, -0.2275609668185795], [-0.05541619987887547, 1.558815480716376, -0.5082809668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2931 {'type': 'polyline', 'positions': [[-0.4154161998788755, 2.326655480716376, -0.3675609668185795], [-0.05541619987887547, 1.558815480716376, -0.5082809668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3031 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [-0.05541619987887547, 1.558815480716376, -0.5082809668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3112 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline416 {'type': 'polyline', 'positions': [[2.2761238001211246, -0.9611845192836241, 0.052439033181420514], [1.8352238001211245, -0.14118451928362408, -0.7475609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline910 {'type': 'polyline', 'positions': [[-1.7154161998788753, 1.2988154807163759, -0.5369709668185795], [-1.8554161998788754, 0.49881548071637605, -0.9266409668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline911 {'type': 'polyline', 'positions': [[-1.7154161998788753, 1.2988154807163759, -0.5369709668185795], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline912 {'type': 'polyline', 'positions': [[-1.7154161998788753, 1.2988154807163759, -0.5369709668185795], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline109 {'type': 'polyline', 'positions': [[-1.8554161998788754, 0.49881548071637605, -0.9266409668185794], [-1.7154161998788753, 1.2988154807163759, -0.5369709668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1011 {'type': 'polyline', 'positions': [[-1.8554161998788754, 0.49881548071637605, -0.9266409668185794], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1012 {'type': 'polyline', 'positions': [[-1.8554161998788754, 0.49881548071637605, -0.9266409668185794], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline119 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-1.7154161998788753, 1.2988154807163759, -0.5369709668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1110 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-1.8554161998788754, 0.49881548071637605, -0.9266409668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1112 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1113 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [0.5245838001211245, 0.5657454807163758, -0.8875609668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline129 {'type': 'polyline', 'positions': [[1.0717678001211246, 1.2788154807163759, 0.3924390331814205], [-0.4154161998788755, 2.326655480716376, -0.3675609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1210 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-1.8554161998788754, 0.49881548071637605, -0.9266409668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1211 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1213 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [0.5245838001211245, 0.5657454807163758, -0.8875609668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1311 {'type': 'polyline', 'positions': [[0.5245838001211245, 0.5657454807163758, -0.8875609668185794], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1312 {'type': 'polyline', 'positions': [[0.5245838001211245, 0.5657454807163758, -0.8875609668185794], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1316 {'type': 'polyline', 'positions': [[0.5245838001211245, 0.5657454807163758, -0.8875609668185794], [1.8352238001211245, -0.14118451928362408, -0.7475609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline164 {'type': 'polyline', 'positions': [[1.8352238001211245, -0.14118451928362408, -0.7475609668185795], [2.2761238001211246, -0.9611845192836241, 0.052439033181420514]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1613 {'type': 'polyline', 'positions': [[1.8352238001211245, -0.14118451928362408, -0.7475609668185795], [0.5245838001211245, 0.5657454807163758, -0.8875609668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2425 {'type': 'polyline', 'positions': [[1.5245838001211245, -1.975709819283624, 0.49243903318142046], [1.4566838001211246, -2.061184519283624, 0.11243903318142051]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2426 {'type': 'polyline', 'positions': [[1.5245838001211245, -1.975709819283624, 0.49243903318142046], [1.7386238001211245, -1.841184519283624, 0.2324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2524 {'type': 'polyline', 'positions': [[1.4566838001211246, -2.061184519283624, 0.11243903318142051], [1.5245838001211245, -1.975709819283624, 0.49243903318142046]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2526 {'type': 'polyline', 'positions': [[1.4566838001211246, -2.061184519283624, 0.11243903318142051], [1.7386238001211245, -1.841184519283624, 0.2324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2624 {'type': 'polyline', 'positions': [[1.7386238001211245, -1.841184519283624, 0.2324390331814205], [1.5245838001211245, -1.975709819283624, 0.49243903318142046]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2625 {'type': 'polyline', 'positions': [[1.7386238001211245, -1.841184519283624, 0.2324390331814205], [1.4566838001211246, -2.061184519283624, 0.11243903318142051]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2829 {'type': 'polyline', 'positions': [[-0.13725619987887544, 2.5188154807163756, -0.2275609668185795], [-0.4154161998788755, 2.326655480716376, -0.3675609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2830 {'type': 'polyline', 'positions': [[-0.13725619987887544, 2.5188154807163756, -0.2275609668185795], [-0.43541619987887553, 2.1988154807163762, -0.43795796681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2928 {'type': 'polyline', 'positions': [[-0.4154161998788755, 2.326655480716376, -0.3675609668185795], [-0.13725619987887544, 2.5188154807163756, -0.2275609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2930 {'type': 'polyline', 'positions': [[-0.4154161998788755, 2.326655480716376, -0.3675609668185795], [-0.43541619987887553, 2.1988154807163762, -0.43795796681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3028 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [-0.13725619987887544, 2.5188154807163756, -0.2275609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3029 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [-0.4154161998788755, 2.326655480716376, -0.3675609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1724 {'type': 'polyline', 'positions': [[1.8245838001211245, -0.2811845192836242, -0.28563796681857956], [1.5245838001211245, -1.975709819283624, 0.49243903318142046]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1725 {'type': 'polyline', 'positions': [[1.8245838001211245, -0.2811845192836242, -0.28563796681857956], [1.4566838001211246, -2.061184519283624, 0.11243903318142051]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1726 {'type': 'polyline', 'positions': [[1.8245838001211245, -0.2811845192836242, -0.28563796681857956], [1.7386238001211245, -1.841184519283624, 0.2324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2417 {'type': 'polyline', 'positions': [[1.5245838001211245, -1.975709819283624, 0.49243903318142046], [1.8245838001211245, -0.2811845192836242, -0.28563796681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2517 {'type': 'polyline', 'positions': [[1.4566838001211246, -2.061184519283624, 0.11243903318142051], [1.8245838001211245, -0.2811845192836242, -0.28563796681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2617 {'type': 'polyline', 'positions': [[1.7386238001211245, -1.841184519283624, 0.2324390331814205], [1.8245838001211245, -0.2811845192836242, -0.28563796681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline729 {'type': 'polyline', 'positions': [[-1.7754161998788753, 1.7371854807163758, 0.5324390331814205], [-0.4154161998788755, 2.326655480716376, -0.3675609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline297 {'type': 'polyline', 'positions': [[-0.4154161998788755, 2.326655480716376, -0.3675609668185795], [-1.7754161998788753, 1.7371854807163758, 0.5324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline307 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [-1.7754161998788753, 1.7371854807163758, 0.5324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline730 {'type': 'polyline', 'positions': [[-1.7754161998788753, 1.7371854807163758, 0.5324390331814205], [-0.43541619987887553, 2.1988154807163762, -0.43795796681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline728 {'type': 'polyline', 'positions': [[-1.7754161998788753, 1.7371854807163758, 0.5324390331814205], [-0.13725619987887544, 2.5188154807163756, -0.2275609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline287 {'type': 'polyline', 'positions': [[-0.13725619987887544, 2.5188154807163756, -0.2275609668185795], [-1.7754161998788753, 1.7371854807163758, 0.5324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline05 {'type': 'polyline', 'positions': [[-0.09541619987887545, -0.1811845192836241, -1.0765009668185797], [-0.9784761998788754, -0.9011845192836241, 0.25243903318142047]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline010 {'type': 'polyline', 'positions': [[-0.09541619987887545, -0.1811845192836241, -1.0765009668185797], [-1.8554161998788754, 0.49881548071637605, -0.9266409668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline011 {'type': 'polyline', 'positions': [[-0.09541619987887545, -0.1811845192836241, -1.0765009668185797], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline012 {'type': 'polyline', 'positions': [[-0.09541619987887545, -0.1811845192836241, -1.0765009668185797], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline013 {'type': 'polyline', 'positions': [[-0.09541619987887545, -0.1811845192836241, -1.0765009668185797], [0.5245838001211245, 0.5657454807163758, -0.8875609668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline016 {'type': 'polyline', 'positions': [[-0.09541619987887545, -0.1811845192836241, -1.0765009668185797], [1.8352238001211245, -0.14118451928362408, -0.7475609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline031 {'type': 'polyline', 'positions': [[-0.09541619987887545, -0.1811845192836241, -1.0765009668185797], [-0.05541619987887547, 1.558815480716376, -0.5082809668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline112 {'type': 'polyline', 'positions': [[1.0717678001211246, 1.2788154807163759, 0.3924390331814205], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline113 {'type': 'polyline', 'positions': [[1.0717678001211246, 1.2788154807163759, 0.3924390331814205], [0.5245838001211245, 0.5657454807163758, -0.8875609668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline116 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-1.1642861998788754, 2.038815480716376, 0.4724390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline117 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-1.7754161998788753, 1.7371854807163758, 0.5324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline128 {'type': 'polyline', 'positions': [[1.0717678001211246, 1.2788154807163759, 0.3924390331814205], [-0.13725619987887544, 2.5188154807163756, -0.2275609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline131 {'type': 'polyline', 'positions': [[0.5245838001211245, 0.5657454807163758, -0.8875609668185794], [1.0717678001211246, 1.2788154807163759, 0.3924390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline23 {'type': 'polyline', 'positions': [[1.4245838001211246, -2.213661519283624, 0.4124390331814205], [1.7914338001211245, -1.921184519283624, -0.18756096681857948]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline24 {'type': 'polyline', 'positions': [[1.4245838001211246, -2.213661519283624, 0.4124390331814205], [2.2761238001211246, -0.9611845192836241, 0.052439033181420514]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline214 {'type': 'polyline', 'positions': [[1.4245838001211246, -2.213661519283624, 0.4124390331814205], [0.8445838001211246, -2.471076519283624, -0.12756096681857954]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline224 {'type': 'polyline', 'positions': [[1.4245838001211246, -2.213661519283624, 0.4124390331814205], [1.5245838001211245, -1.975709819283624, 0.49243903318142046]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline225 {'type': 'polyline', 'positions': [[1.4245838001211246, -2.213661519283624, 0.4124390331814205], [1.4566838001211246, -2.061184519283624, 0.11243903318142051]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline226 {'type': 'polyline', 'positions': [[1.4245838001211246, -2.213661519283624, 0.4124390331814205], [1.7386238001211245, -1.841184519283624, 0.2324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline34 {'type': 'polyline', 'positions': [[1.7914338001211245, -1.921184519283624, -0.18756096681857948], [2.2761238001211246, -0.9611845192836241, 0.052439033181420514]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline314 {'type': 'polyline', 'positions': [[1.7914338001211245, -1.921184519283624, -0.18756096681857948], [0.8445838001211246, -2.471076519283624, -0.12756096681857954]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline316 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [-1.1642861998788754, 2.038815480716376, 0.4724390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline317 {'type': 'polyline', 'positions': [[1.7914338001211245, -1.921184519283624, -0.18756096681857948], [1.8245838001211245, -0.2811845192836242, -0.28563796681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline324 {'type': 'polyline', 'positions': [[1.7914338001211245, -1.921184519283624, -0.18756096681857948], [1.5245838001211245, -1.975709819283624, 0.49243903318142046]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline325 {'type': 'polyline', 'positions': [[1.7914338001211245, -1.921184519283624, -0.18756096681857948], [1.4566838001211246, -2.061184519283624, 0.11243903318142051]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline326 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-1.1642861998788754, 2.038815480716376, 0.4724390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline42 {'type': 'polyline', 'positions': [[2.2761238001211246, -0.9611845192836241, 0.052439033181420514], [1.4245838001211246, -2.213661519283624, 0.4124390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline43 {'type': 'polyline', 'positions': [[2.2761238001211246, -0.9611845192836241, 0.052439033181420514], [1.7914338001211245, -1.921184519283624, -0.18756096681857948]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline417 {'type': 'polyline', 'positions': [[2.2761238001211246, -0.9611845192836241, 0.052439033181420514], [1.8245838001211245, -0.2811845192836242, -0.28563796681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline424 {'type': 'polyline', 'positions': [[2.2761238001211246, -0.9611845192836241, 0.052439033181420514], [1.5245838001211245, -1.975709819283624, 0.49243903318142046]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline425 {'type': 'polyline', 'positions': [[2.2761238001211246, -0.9611845192836241, 0.052439033181420514], [1.4566838001211246, -2.061184519283624, 0.11243903318142051]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline426 {'type': 'polyline', 'positions': [[2.2761238001211246, -0.9611845192836241, 0.052439033181420514], [1.7386238001211245, -1.841184519283624, 0.2324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline67 {'type': 'polyline', 'positions': [[-1.1642861998788754, 2.038815480716376, 0.4724390331814205], [-1.7754161998788753, 1.7371854807163758, 0.5324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline69 {'type': 'polyline', 'positions': [[-1.1642861998788754, 2.038815480716376, 0.4724390331814205], [-1.7154161998788753, 1.2988154807163759, -0.5369709668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline611 {'type': 'polyline', 'positions': [[-1.1642861998788754, 2.038815480716376, 0.4724390331814205], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline612 {'type': 'polyline', 'positions': [[-1.1642861998788754, 2.038815480716376, 0.4724390331814205], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline627 {'type': 'polyline', 'positions': [[-1.1642861998788754, 2.038815480716376, 0.4724390331814205], [-2.115416199878876, 0.998815480716376, -0.17230596681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline628 {'type': 'polyline', 'positions': [[-1.1642861998788754, 2.038815480716376, 0.4724390331814205], [-0.13725619987887544, 2.5188154807163756, -0.2275609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline629 {'type': 'polyline', 'positions': [[-1.1642861998788754, 2.038815480716376, 0.4724390331814205], [-0.4154161998788755, 2.326655480716376, -0.3675609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline630 {'type': 'polyline', 'positions': [[-1.1642861998788754, 2.038815480716376, 0.4724390331814205], [-0.43541619987887553, 2.1988154807163762, -0.43795796681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline631 {'type': 'polyline', 'positions': [[-1.1642861998788754, 2.038815480716376, 0.4724390331814205], [-0.05541619987887547, 1.558815480716376, -0.5082809668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline632 {'type': 'polyline', 'positions': [[-1.1642861998788754, 2.038815480716376, 0.4724390331814205], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline79 {'type': 'polyline', 'positions': [[-1.7754161998788753, 1.7371854807163758, 0.5324390331814205], [-1.7154161998788753, 1.2988154807163759, -0.5369709668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline710 {'type': 'polyline', 'positions': [[-1.7754161998788753, 1.7371854807163758, 0.5324390331814205], [-1.8554161998788754, 0.49881548071637605, -0.9266409668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline711 {'type': 'polyline', 'positions': [[-1.7754161998788753, 1.7371854807163758, 0.5324390331814205], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline712 {'type': 'polyline', 'positions': [[-1.7754161998788753, 1.7371854807163758, 0.5324390331814205], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline727 {'type': 'polyline', 'positions': [[-1.7754161998788753, 1.7371854807163758, 0.5324390331814205], [-2.115416199878876, 0.998815480716376, -0.17230596681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline732 {'type': 'polyline', 'positions': [[-1.7754161998788753, 1.7371854807163758, 0.5324390331814205], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline96 {'type': 'polyline', 'positions': [[-1.7154161998788753, 1.2988154807163759, -0.5369709668185795], [-1.1642861998788754, 2.038815480716376, 0.4724390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline97 {'type': 'polyline', 'positions': [[-1.7154161998788753, 1.2988154807163759, -0.5369709668185795], [-1.7754161998788753, 1.7371854807163758, 0.5324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline927 {'type': 'polyline', 'positions': [[-1.7154161998788753, 1.2988154807163759, -0.5369709668185795], [-2.115416199878876, 0.998815480716376, -0.17230596681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline929 {'type': 'polyline', 'positions': [[-1.7154161998788753, 1.2988154807163759, -0.5369709668185795], [-0.4154161998788755, 2.326655480716376, -0.3675609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline930 {'type': 'polyline', 'positions': [[-1.7154161998788753, 1.2988154807163759, -0.5369709668185795], [-0.43541619987887553, 2.1988154807163762, -0.43795796681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline931 {'type': 'polyline', 'positions': [[-1.7154161998788753, 1.2988154807163759, -0.5369709668185795], [-0.05541619987887547, 1.558815480716376, -0.5082809668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline932 {'type': 'polyline', 'positions': [[-1.7154161998788753, 1.2988154807163759, -0.5369709668185795], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline107 {'type': 'polyline', 'positions': [[-1.8554161998788754, 0.49881548071637605, -0.9266409668185794], [-1.7754161998788753, 1.7371854807163758, 0.5324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1027 {'type': 'polyline', 'positions': [[-1.8554161998788754, 0.49881548071637605, -0.9266409668185794], [-2.115416199878876, 0.998815480716376, -0.17230596681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1032 {'type': 'polyline', 'positions': [[-1.8554161998788754, 0.49881548071637605, -0.9266409668185794], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1127 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-2.115416199878876, 0.998815480716376, -0.17230596681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1128 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-0.13725619987887544, 2.5188154807163756, -0.2275609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1129 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-0.4154161998788755, 2.326655480716376, -0.3675609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1130 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-0.43541619987887553, 2.1988154807163762, -0.43795796681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1131 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-0.05541619987887547, 1.558815480716376, -0.5082809668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1132 {'type': 'polyline', 'positions': [[-1.2484261998788755, 0.978815480716376, -0.40756096681857956], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline121 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [1.0717678001211246, 1.2788154807163759, 0.3924390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline126 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-1.1642861998788754, 2.038815480716376, 0.4724390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline127 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-1.7754161998788753, 1.7371854807163758, 0.5324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1227 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-2.115416199878876, 0.998815480716376, -0.17230596681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1228 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-0.13725619987887544, 2.5188154807163756, -0.2275609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1229 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-0.4154161998788755, 2.326655480716376, -0.3675609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1230 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-0.43541619987887553, 2.1988154807163762, -0.43795796681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1231 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-0.05541619987887547, 1.558815480716376, -0.5082809668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1232 {'type': 'polyline', 'positions': [[-0.35541619987887546, 1.038815480716376, -0.5444409668185796], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1317 {'type': 'polyline', 'positions': [[0.5245838001211245, 0.5657454807163758, -0.8875609668185794], [1.8245838001211245, -0.2811845192836242, -0.28563796681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# ...
# polyline1617 {'type': 'polyline', 'positions': [[1.8352238001211245, -0.14118451928362408, -0.7475609668185795], [1.8245838001211245, -0.2811845192836242, -0.28563796681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1626 {'type': 'polyline', 'positions': [[1.8352238001211245, -0.14118451928362408, -0.7475609668185795], [1.7386238001211245, -1.841184519283624, 0.2324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline171 {'type': 'polyline', 'positions': [[1.8245838001211245, -0.2811845192836242, -0.28563796681857956], [1.0717678001211246, 1.2788154807163759, 0.3924390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline173 {'type': 'polyline', 'positions': [[1.8245838001211245, -0.2811845192836242, -0.28563796681857956], [1.7914338001211245, -1.921184519283624, -0.18756096681857948]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline174 {'type': 'polyline', 'positions': [[1.8245838001211245, -0.2811845192836242, -0.28563796681857956], [2.2761238001211246, -0.9611845192836241, 0.052439033181420514]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline1713 {'type': 'polyline', 'positions': [[1.8245838001211245, -0.2811845192836242, -0.28563796681857956], [0.5245838001211245, 0.5657454807163758, -0.8875609668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline242 {'type': 'polyline', 'positions': [[1.5245838001211245, -1.975709819283624, 0.49243903318142046], [1.4245838001211246, -2.213661519283624, 0.4124390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline244 {'type': 'polyline', 'positions': [[1.5245838001211245, -1.975709819283624, 0.49243903318142046], [2.2761238001211246, -0.9611845192836241, 0.052439033181420514]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2414 {'type': 'polyline', 'positions': [[1.5245838001211245, -1.975709819283624, 0.49243903318142046], [0.8445838001211246, -2.471076519283624, -0.12756096681857954]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline252 {'type': 'polyline', 'positions': [[1.4566838001211246, -2.061184519283624, 0.11243903318142051], [1.4245838001211246, -2.213661519283624, 0.4124390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline254 {'type': 'polyline', 'positions': [[1.4566838001211246, -2.061184519283624, 0.11243903318142051], [2.2761238001211246, -0.9611845192836241, 0.052439033181420514]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2514 {'type': 'polyline', 'positions': [[1.4566838001211246, -2.061184519283624, 0.11243903318142051], [0.8445838001211246, -2.471076519283624, -0.12756096681857954]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline262 {'type': 'polyline', 'positions': [[1.7386238001211245, -1.841184519283624, 0.2324390331814205], [1.4245838001211246, -2.213661519283624, 0.4124390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline264 {'type': 'polyline', 'positions': [[1.7386238001211245, -1.841184519283624, 0.2324390331814205], [2.2761238001211246, -0.9611845192836241, 0.052439033181420514]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2614 {'type': 'polyline', 'positions': [[1.7386238001211245, -1.841184519283624, 0.2324390331814205], [0.8445838001211246, -2.471076519283624, -0.12756096681857954]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2616 {'type': 'polyline', 'positions': [[1.7386238001211245, -1.841184519283624, 0.2324390331814205], [1.8352238001211245, -0.14118451928362408, -0.7475609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline276 {'type': 'polyline', 'positions': [[-2.115416199878876, 0.998815480716376, -0.17230596681857946], [-1.1642861998788754, 2.038815480716376, 0.4724390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline277 {'type': 'polyline', 'positions': [[-2.115416199878876, 0.998815480716376, -0.17230596681857946], [-1.7754161998788753, 1.7371854807163758, 0.5324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2710 {'type': 'polyline', 'positions': [[-2.115416199878876, 0.998815480716376, -0.17230596681857946], [-1.8554161998788754, 0.49881548071637605, -0.9266409668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2711 {'type': 'polyline', 'positions': [[-2.115416199878876, 0.998815480716376, -0.17230596681857946], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2712 {'type': 'polyline', 'positions': [[-2.115416199878876, 0.998815480716376, -0.17230596681857946], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2732 {'type': 'polyline', 'positions': [[-2.115416199878876, 0.998815480716376, -0.17230596681857946], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline281 {'type': 'polyline', 'positions': [[-0.13725619987887544, 2.5188154807163756, -0.2275609668185795], [1.0717678001211246, 1.2788154807163759, 0.3924390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline286 {'type': 'polyline', 'positions': [[-0.13725619987887544, 2.5188154807163756, -0.2275609668185795], [-1.1642861998788754, 2.038815480716376, 0.4724390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2811 {'type': 'polyline', 'positions': [[-0.13725619987887544, 2.5188154807163756, -0.2275609668185795], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2812 {'type': 'polyline', 'positions': [[-0.13725619987887544, 2.5188154807163756, -0.2275609668185795], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2832 {'type': 'polyline', 'positions': [[-0.13725619987887544, 2.5188154807163756, -0.2275609668185795], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline291 {'type': 'polyline', 'positions': [[-0.4154161998788755, 2.326655480716376, -0.3675609668185795], [1.0717678001211246, 1.2788154807163759, 0.3924390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline296 {'type': 'polyline', 'positions': [[-0.4154161998788755, 2.326655480716376, -0.3675609668185795], [-1.1642861998788754, 2.038815480716376, 0.4724390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline299 {'type': 'polyline', 'positions': [[-0.4154161998788755, 2.326655480716376, -0.3675609668185795], [-1.7154161998788753, 1.2988154807163759, -0.5369709668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2911 {'type': 'polyline', 'positions': [[-0.4154161998788755, 2.326655480716376, -0.3675609668185795], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2912 {'type': 'polyline', 'positions': [[-0.4154161998788755, 2.326655480716376, -0.3675609668185795], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline2932 {'type': 'polyline', 'positions': [[-0.4154161998788755, 2.326655480716376, -0.3675609668185795], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline301 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [1.0717678001211246, 1.2788154807163759, 0.3924390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline306 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [-1.1642861998788754, 2.038815480716376, 0.4724390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline309 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [-1.7154161998788753, 1.2988154807163759, -0.5369709668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3011 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3012 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3013 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [0.5245838001211245, 0.5657454807163758, -0.8875609668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3032 {'type': 'polyline', 'positions': [[-0.43541619987887553, 2.1988154807163762, -0.43795796681857946], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline310 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [-0.09541619987887545, -0.1811845192836241, -1.0765009668185797]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline311 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [1.0717678001211246, 1.2788154807163759, 0.3924390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline319 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [-1.7154161998788753, 1.2988154807163759, -0.5369709668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3111 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3113 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [0.5245838001211245, 0.5657454807163758, -0.8875609668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3128 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [-0.13725619987887544, 2.5188154807163756, -0.2275609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3129 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [-0.4154161998788755, 2.326655480716376, -0.3675609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3130 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [-0.43541619987887553, 2.1988154807163762, -0.43795796681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3132 {'type': 'polyline', 'positions': [[-0.05541619987887547, 1.558815480716376, -0.5082809668185796], [-1.3354161998788754, 1.518815480716376, 0.20918803318142049]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline327 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-1.7754161998788753, 1.7371854807163758, 0.5324390331814205]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline329 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-1.7154161998788753, 1.2988154807163759, -0.5369709668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3210 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-1.8554161998788754, 0.49881548071637605, -0.9266409668185794]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3211 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-1.2484261998788755, 0.978815480716376, -0.40756096681857956]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3212 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-0.35541619987887546, 1.038815480716376, -0.5444409668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3227 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-2.115416199878876, 0.998815480716376, -0.17230596681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3228 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-0.13725619987887544, 2.5188154807163756, -0.2275609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3229 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-0.4154161998788755, 2.326655480716376, -0.3675609668185795]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3230 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-0.43541619987887553, 2.1988154807163762, -0.43795796681857946]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# polyline3231 {'type': 'polyline', 'positions': [[-1.3354161998788754, 1.518815480716376, 0.20918803318142049], [-0.05541619987887547, 1.558815480716376, -0.5082809668185796]], 'color': [250.0, 250.0, 250.0], 'alpha': 0.5, 'edge_width': 0.02, 'visible': True}
# Info: Total files 0 | Changed 0 | Failed 0
# Info: Saved "blender_scene.blend"
# Saved blender file to: /local/home/ekoller/visscenegraph/8eabc426-5af7-2f32-87bb-a16609b099e3/pcs_nodes/blender_scene.blend
#
# Blender quit
#
# ************************************************************************
# Blender instructions
# cd /local/home/ekoller/visscenegraph/8eabc426-5af7-2f32-87bb-a16609b099e3/pcs_nodes; /local/home/ekoller/visscenegraph/blender-4.1.1-linux-x64/blender --background --python blender_script.py
# ************************************************************************
