# %%
import pyviz3d.visualizer as viz
import numpy as np
import math
import open3d as o3d

import numpy as np
import pyviz3d.visualizer as viz
# import pyviz3d.src.blender_tools as blt 
import plyfile
import open3d as o3d
import os
from sklearn.neighbors import NearestNeighbors

#from Yang
def read_ply_data(filename):
    filename_in = filename
    file = open(filename_in, 'rb')
    ply_data = plyfile.PlyData.read(file)
    file.close()
    x = ply_data['vertex']['x']
    y = ply_data['vertex']['y']
    z = ply_data['vertex']['z']
    red = ply_data['vertex']['red']
    green = ply_data['vertex']['green']
    blue = ply_data['vertex']['blue']
    object_id = ply_data['vertex']['objectId']
    global_id = ply_data['vertex']['globalId']
    nyu40_id = ply_data['vertex']['NYU40']
    eigen13_id = ply_data['vertex']['Eigen13']
    rio27_id = ply_data['vertex']['RIO27']
 
    vertices = np.empty(len(x), dtype=[('x', 'f4'), ('y', 'f4'), ('z', 'f4'),  ('red', 'u1'), ('green', 'u1'), ('blue', 'u1'),
                                                     ('objectId', 'h'), ('globalId', 'h'), ('NYU40', 'u1'), ('Eigen13', 'u1'), ('RIO27', 'u1')])
    
    vertices['x'] = x.astype('f4')
    vertices['y'] = y.astype('f4')
    vertices['z'] = z.astype('f4')
    vertices['red'] = red.astype('u1')
    vertices['green'] = green.astype('u1')
    vertices['blue'] = blue.astype('u1')
    vertices['objectId'] = object_id.astype('h')
    vertices['globalId'] = global_id.astype('h')
    vertices['NYU40'] = nyu40_id.astype('u1')
    vertices['Eigen13'] = eigen13_id.astype('u1')
    vertices['RIO27'] = rio27_id.astype('u1')
    return vertices
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def generate_ball_pcl(position, radius, color, resolution=5):
    # generate ball
    points = []
    ## generate ball points
    for i in range(0, 360, resolution):
        for j in range(0, 360, resolution):
            x = radius * np.cos(np.deg2rad(i)) * np.sin(np.deg2rad(j))
            y = radius * np.sin(np.deg2rad(i)) * np.sin(np.deg2rad(j))
            z = radius * np.cos(np.deg2rad(j))
            points.append([x, y, z])
    points = np.array(points)
    ## translate ball
    points += position
    colors = np.array([color for _ in range((points.shape[0]))])
    return points, colors

def generate_camera_frustum(vis, cam_extrinsics, target_scene_center = np.array([0, 0, 0]),
                            cam_color = [0, 0, 0],
                            img_width_m = 0.7, cam_depth_range = 0.8, 
                            point_size = 0.04, img_size = (540, 960)):
    image_h = img_size[1]
    image_w = img_size[0]
    img_height_m = img_width_m * image_h / image_w
    
    # get points in camera frustum
    image_center = np.array([0, 0, 0])
    image_corners =  np.array([
        [img_width_m/2.0, img_height_m/2.0, cam_depth_range],
        [-img_width_m/2.0, img_height_m/2.0, cam_depth_range],
        [-img_width_m/2.0, -img_height_m/2.0, cam_depth_range],
        [img_width_m/2.0, -img_height_m/2.0, cam_depth_range],
    ])
    T_rescan2ref_right, T_camera2rescan = cam_extrinsics[0], cam_extrinsics[1]
    # transform to world coord
    image_center =  image_center @ (T_camera2rescan[:3, :3]).T  + T_camera2rescan[:3, 3].T
    image_corners = image_corners @ (T_camera2rescan[:3, :3]).T  + T_camera2rescan[:3, 3].T
    image_center =  image_center @ T_rescan2ref_right[:3, :3]  + T_rescan2ref_right[3, :3]
    image_corners = image_corners @ T_rescan2ref_right[:3, :3]  + T_rescan2ref_right[3, :3]
    image_center = image_center + target_scene_center.reshape(1, 3)
    image_corners = image_corners + target_scene_center.reshape(1, 3)
    # get lines in camera frustum
    line_ps_start = []
    line_ps_end = []
    black_color = np.array([0.0, 0.0, 0.0])
    vis.add_points('img_center', image_center.reshape(-1, 3), black_color.reshape(-1, 3), point_size=100, resolution=15, visible=True)    
    for i in range(4):
        # line_ps_start.append(image_center.reshape(3))
        # line_ps_end.append(image_corners[i].reshape(3))
        edges = []
        edges.append(image_center.reshape(3))
        edges.append(image_corners[i].reshape(3))
        # obj = cylinder_between(x1, y1, z1, x2, y2, z2, properties['edge_width'] * 2, properties['color'])
        # create_mat(obj)
        vis.add_polyline(f'img_center_corner{i}', np.array(edges), color=np.array([0, 0, 0]), edge_width=0.015)
        vis.add_points(f'corner{i}', image_center.reshape(-1,3), black_color.reshape(-1, 3), point_size=25, resolution=15, visible=True)    
    for i in range(4):
        # line_ps_start.append(image_corners[i].reshape(3))
        # line_ps_end.append(image_corners[(i+1)%4].reshape(3))
        edges = []
        edges.append(image_corners[i].reshape(3))
        edges.append(image_corners[(i+1)%4].reshape(3))
        vis.add_polyline(f'center{[i]}_corner{i+1}', np.array(edges), color=np.array([0, 0, 0]), edge_width=0.015)
    # line_ps_start = np.array(line_ps_start)
    # line_ps_end = np.array(line_ps_end)
    # # generate point balls
    # points_center, colors_center = generate_ball_pcl(image_center, point_size, cam_color)
   

def save_visualize(mesh_file, out_folder, img_pose = None, img_size = (540, 960), 
                   node_size = 200, matched_node_size = 400, matched_ids = np.array([]),
                   render_cam_pose = [-0.265198, -0.411423, 7.11054],
                   render_cam_look = [0.0, 0.0, 0.0], obj_count_th = 1000,
                   blender_path = None):
    scene = o3d.io.read_point_cloud(mesh_file)

    scene_meta = read_ply_data(mesh_file)

    scene.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))

    point_normals = np.asarray(scene.normals)
    point_positions = np.asarray(scene.points)
    points_center = np.mean(point_positions, axis=0)
    point_positions -= points_center
    point_colors = np.asarray(scene.colors)
    objectIds = scene_meta['objectId']
    
    # filter out points with color (0, 0, 0)
    mask = np.any(point_colors > 0, axis=1)
    point_positions = point_positions[mask]
    point_normals = point_normals[mask]
    point_colors = point_colors[mask]
    objectIds = objectIds[mask]
    ## filter out points with number of points less than 100
    unique_objectIds, counts = np.unique(objectIds, return_counts=True)
    mask = np.isin(objectIds, unique_objectIds[counts > obj_count_th])
    point_positions = point_positions[mask]
    point_normals = point_normals[mask]
    point_colors = point_colors[mask]
    objectIds = objectIds[mask]
    
    print("point_positions.shape", point_positions.shape)
    print("point_normals.shape", point_normals.shape)
    print("point_colors.shape", point_colors.shape)
    print("objectIds.shape", objectIds.shape)

    # Find instance centers and colors
    
    unique_objectIds = np.unique(objectIds)
    obj_centers = []
    obj_colors = []
    obj_ids = []
    for obj_id in unique_objectIds:
        obj_points = point_positions[objectIds == obj_id]
        obj_center = np.mean(obj_points, axis=0)
        obj_color = point_colors[objectIds == obj_id][0, :]
        
        obj_positions_relative = obj_points - obj_center
        dist_norm = np.linalg.norm(obj_positions_relative, axis=1)
        nearest_idx = np.argsort(dist_norm)[0]
        obj_patch_pos = obj_points[nearest_idx]
        obj_center = obj_patch_pos
        
        obj_centers.append(obj_center)
        obj_colors.append(obj_color)
        obj_ids.append(obj_id)
    obj_centers = np.concatenate(obj_centers).reshape(-1, 3)
    obj_colors = np.concatenate(obj_colors).reshape(-1, 3)
    mask = obj_centers[:, 2] < 0.8
    obj_centers = obj_centers[mask]
    obj_colors = obj_colors[mask]
    obj_ids = np.array(obj_ids)[mask]
    
    vis_nodes = viz.Visualizer(position=render_cam_pose, look_at =  render_cam_look, focal_length=28)
    vis_pcs = viz.Visualizer(position=render_cam_pose, look_at =  render_cam_look, focal_length=28)
    vis_pcs_nodes = viz.Visualizer(position=render_cam_pose, look_at =  render_cam_look, focal_length=28)
    pcs_mask = point_positions[:,2] < 0.8
    for idx, obj_id in enumerate(obj_ids):
        obj_center = obj_centers[idx]
        obj_color = obj_colors[idx]
        obj_size = node_size if obj_id not in matched_ids else matched_node_size

        vis_nodes.add_points('obj_{}'.format(obj_id), obj_center.reshape(-1,3), 
                            obj_color.reshape(-1,3) * 255, point_size=obj_size, resolution=15, visible=True)  
        vis_pcs_nodes.add_points('obj_{}'.format(obj_id), obj_center.reshape(-1,3), 
                            obj_color.reshape(-1,3) * 255, point_size=obj_size, resolution=15, visible=True)  

        obj_mask = np.logical_and( objectIds == obj_id, pcs_mask)
        
        if len(matched_ids) == 0:
            alpha = 1.0
            vis_pcs.add_points('pcs_obj_{}'.format(obj_id), point_positions[obj_mask], point_colors[obj_mask] * 255, point_normals[obj_mask], 
                point_size=50, visible=True, alpha=alpha)
        else:
            alpha = 0.1 if obj_id not in matched_ids else 1.0
            vis_pcs.add_points('pcs_obj_{}'.format(obj_id), point_positions[obj_mask], point_colors[obj_mask] * 255, point_normals[obj_mask], 
                point_size=50, visible=True, alpha=alpha)
            
        vis_pcs_nodes.add_points('pcs_obj_{}'.format(obj_id), point_positions[obj_mask], point_colors[obj_mask] * 255, point_normals[obj_mask], 
            point_size=50, visible=True, alpha=0.1)
                
    nbrs = NearestNeighbors(n_neighbors=5, algorithm='ball_tree').fit(obj_centers)
    distances, indices = nbrs.kneighbors(obj_centers)
    for i in range(indices.shape[0]):
        for jj, j in enumerate(indices[i].tolist()):
            if distances[i][jj] < 2.0 and distances[i][jj] > 0.001:
                edges = []
                edges.append(obj_centers[i])
                edges.append(obj_centers[j])
                vis_nodes.add_polyline(f'polyline{i}{j}', np.array(edges), color=np.array([250.0, 250.0, 250.0]), edge_width=0.02)
                vis_pcs_nodes.add_polyline(f'polyline{i}{j}', np.array(edges), color=np.array([250.0, 250.0, 250.0]), edge_width=0.02)

    
    
    if img_pose is not None:
        # line_ps_start, line_ps_end, points_frustum, colors_frustum = \
        #     generate_camera_frustum(img_pose, img_size=img_size, img_width_m=0.4)
        # # add image frustum
        # vis_pcs.add_points(
        #     'frustum', 
        #     positions=points_frustum,
        #     colors=colors_frustum)
        # vis_pcs.add_lines(
        #     'frustum_lines', 
        #     line_ps_start, line_ps_end)
        generate_camera_frustum( vis_pcs, img_pose, img_size=img_size, img_width_m=0.6, cam_depth_range=0.4, target_scene_center=-points_center)
        
    # When we added everything we need to the visualizer, we save it.
    out_folder_pcs = os.path.join(out_folder, "pcs")
    out_folder_nodes = os.path.join(out_folder, "nodes")
    out_folder_pcs_nodes = os.path.join(out_folder, "pcs_nodes")

    #make sure the directories exist
    for dir_path in [out_folder_pcs, out_folder_nodes, out_folder_pcs_nodes]:
        try:
            os.makedirs(dir_path, exist_ok=True)
            
        except Exception as e:
            print(f"Failed to create directory {dir_path}: {e}")

    blender_args = {
    "executable_path": blender_path,
    "output_prefix" : False
    }
            
    vis_pcs.save(path =out_folder_pcs, port= 8080,blender_args= blender_args, verbose= True)
    vis_nodes.save(path = out_folder_nodes, port= 8080, blender_args= blender_args, verbose= True )
    vis_pcs_nodes.save(path = out_folder_pcs_nodes, port= 8080,blender_args= blender_args, verbose= True)
    # return {
    #     'img_pose': img_pose,
    #     'line_ps_start': line_ps_start,
    #     'line_ps_end': line_ps_end,
    #     'points_frustum': points_frustum,
    #     'colors_frustum': colors_frustum,
        
    # }

# %%
# 20c993b3-698f-29c5-859c-dca8ddecf220
scan_id = "20c993b3-698f-29c5-859c-dca8ddecf220"

mesh_file = os.path.join('/local/home/ekoller/R3Scan/scenes', scan_id, "labels.instances.align.annotated.v2.ply")
out_folder = os.path.join("/local/home/ekoller/visscenegraph",scan_id)
blender_path = "/local/home/ekoller/visscenegraph/blender-4.1.1-linux-x64/blender"
save_visualize(mesh_file, out_folder, img_size=(960, 540), 
               node_size=200, matched_node_size=500,
               render_cam_pose = [-0.5, -2.5, 2.8], render_cam_look = [0.0, 0.0, -0.3], obj_count_th=100, blender_path=blender_path)
# Out:
# point_positions.shape (28241, 3)
# point_normals.shape (28241, 3)
# point_colors.shape (28241, 3)
# objectIds.shape (28241,)
#
# ************************************************************************
# 1) Start local server:
#     cd /local/home/ekoller/visscenegraph/20c993b3-698f-29c5-859c-dca8ddecf220/pcs; python -m http.server 8080
# 2) Open in browser:
#     http://localhost:8080
# ************************************************************************
# Blender 4.1.1 (hash e1743a0317bc built 2024-04-15 23:47:45)
# <bpy_struct, Object("Cube") at 0x7efc06939708>
# <bpy_struct, Object("Light") at 0x7efc06939c08>
# <bpy_struct, Object("Camera") at 0x7efc06939208>
# Camera_0 {'type': 'camera', 'position': [-0.5, -2.5, 2.799999952316284], 'look_at': [0.0, 0.0, -0.30000001192092896], 'up': [0.0, 0.0, 1.0], 'focal_length': 28.0, 'animation': False}
# pcs_obj_1 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 2621, 'binary_filename': 'pcs_obj_1.bin'}
# PLY import of 'pcs_obj_1.ply' took 98.10 ms
# pcs_obj_2 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 1429, 'binary_filename': 'pcs_obj_2.bin'}
# PLY import of 'pcs_obj_2.ply' took 34.68 ms
# pcs_obj_3 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 330, 'binary_filename': 'pcs_obj_3.bin'}
# PLY import of 'pcs_obj_3.ply' took 5.93 ms
# pcs_obj_4 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 524, 'binary_filename': 'pcs_obj_4.bin'}
# PLY import of 'pcs_obj_4.ply' took 11.02 ms
# pcs_obj_5 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 1441, 'binary_filename': 'pcs_obj_5.bin'}
# PLY import of 'pcs_obj_5.ply' took 56.90 ms
# pcs_obj_6 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 9009, 'binary_filename': 'pcs_obj_6.bin'}
# PLY import of 'pcs_obj_6.ply' took 347.16 ms
# pcs_obj_7 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 1771, 'binary_filename': 'pcs_obj_7.bin'}
# PLY import of 'pcs_obj_7.ply' took 40.08 ms
# pcs_obj_8 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 248, 'binary_filename': 'pcs_obj_8.bin'}
# PLY import of 'pcs_obj_8.ply' took 5.49 ms
# pcs_obj_9 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 4079, 'binary_filename': 'pcs_obj_9.bin'}
# PLY import of 'pcs_obj_9.ply' took 155.31 ms
# pcs_obj_12 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 1, 'point_size': 50, 'num_points': 147, 'binary_filename': 'pcs_obj_12.bin'}
# PLY import of 'pcs_obj_12.ply' took 2.66 ms
# Info: Total files 0 | Changed 0 | Failed 0
# Info: Saved "blender_scene.blend"
# Saved blender file to: /local/home/ekoller/visscenegraph/20c993b3-698f-29c5-859c-dca8ddecf220/pcs/blender_scene.blend
#
# Blender quit
#
# ************************************************************************
# Blender instructions
# cd /local/home/ekoller/visscenegraph/20c993b3-698f-29c5-859c-dca8ddecf220/pcs; /local/home/ekoller/visscenegraph/blender-4.1.1-linux-x64/blender --background --python blender_script.py
# ************************************************************************
#
# ************************************************************************
# 1) Start local server:
#     cd /local/home/ekoller/visscenegraph/20c993b3-698f-29c5-859c-dca8ddecf220/nodes; python -m http.server 8080
# 2) Open in browser:
#     http://localhost:8080
# ************************************************************************
# Blender 4.1.1 (hash e1743a0317bc built 2024-04-15 23:47:45)
# <bpy_struct, Object("Cube") at 0x7fa5ac73b708>
# <bpy_struct, Object("Light") at 0x7fa5ac73bc08>
# <bpy_struct, Object("Camera") at 0x7fa5ac73b208>
# Camera_0 {'type': 'camera', 'position': [-0.5, -2.5, 2.799999952316284], 'look_at': [0.0, 0.0, -0.30000001192092896], 'up': [0.0, 0.0, 1.0], 'focal_length': 28.0, 'animation': False}
# obj_1 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_1.bin'}
# PLY import of 'obj_1.ply' took 0.48 ms
# obj_2 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_2.bin'}
# PLY import of 'obj_2.ply' took 0.51 ms
# obj_3 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_3.bin'}
# PLY import of 'obj_3.ply' took 0.47 ms
# obj_4 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_4.bin'}
# PLY import of 'obj_4.ply' took 0.47 ms
# obj_5 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_5.bin'}
# PLY import of 'obj_5.ply' took 0.47 ms
# obj_6 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_6.bin'}
# PLY import of 'obj_6.ply' took 0.46 ms
# obj_7 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_7.bin'}
# PLY import of 'obj_7.ply' took 0.43 ms
# obj_8 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_8.bin'}
# PLY import of 'obj_8.ply' took 0.43 ms
# obj_9 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_9.bin'}
# PLY import of 'obj_9.ply' took 0.43 ms
# obj_12 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_12.bin'}
# PLY import of 'obj_12.ply' took 0.56 ms
# polyline01 {'type': 'polyline', 'positions': [[-0.2764336395121921, -0.4038486696619006, -1.291274437174449], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline02 {'type': 'polyline', 'positions': [[-0.2764336395121921, -0.4038486696619006, -1.291274437174449], [-0.7119709852196086, -0.7503663517374011, -1.1731191961618757]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline03 {'type': 'polyline', 'positions': [[-0.2764336395121921, -0.4038486696619006, -1.291274437174449], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline09 {'type': 'polyline', 'positions': [[-0.2764336395121921, -0.4038486696619006, -1.291274437174449], [-1.4155787828422892, -1.0755001522439929, -1.22531903670753]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline10 {'type': 'polyline', 'positions': [[-0.5594682696319926, -0.3843980051416369, -1.0238404362055158], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline12 {'type': 'polyline', 'positions': [[-0.5594682696319926, -0.3843980051416369, -1.0238404362055158], [-0.7119709852196086, -0.7503663517374011, -1.1731191961618757]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline13 {'type': 'polyline', 'positions': [[-0.5594682696319926, -0.3843980051416369, -1.0238404362055158], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline19 {'type': 'polyline', 'positions': [[-0.5594682696319926, -0.3843980051416369, -1.0238404362055158], [-1.4155787828422892, -1.0755001522439929, -1.22531903670753]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline21 {'type': 'polyline', 'positions': [[-0.7119709852196086, -0.7503663517374011, -1.1731191961618757], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline20 {'type': 'polyline', 'positions': [[-0.7119709852196086, -0.7503663517374011, -1.1731191961618757], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline29 {'type': 'polyline', 'positions': [[-0.7119709852196086, -0.7503663517374011, -1.1731191961618757], [-1.4155787828422892, -1.0755001522439929, -1.22531903670753]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline23 {'type': 'polyline', 'positions': [[-0.7119709852196086, -0.7503663517374011, -1.1731191961618757], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline30 {'type': 'polyline', 'positions': [[0.10622605653034561, -0.08493544830264765, -0.8353701917978621], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline31 {'type': 'polyline', 'positions': [[0.10622605653034561, -0.08493544830264765, -0.8353701917978621], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline34 {'type': 'polyline', 'positions': [[0.10622605653034561, -0.08493544830264765, -0.8353701917978621], [0.6874351498626363, 0.08116672264156621, -0.2089673070761061]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline32 {'type': 'polyline', 'positions': [[0.10622605653034561, -0.08493544830264765, -0.8353701917978621], [-0.7119709852196086, -0.7503663517374011, -1.1731191961618757]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline43 {'type': 'polyline', 'positions': [[0.6874351498626363, 0.08116672264156621, -0.2089673070761061], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline45 {'type': 'polyline', 'positions': [[0.6874351498626363, 0.08116672264156621, -0.2089673070761061], [-0.39932648865951187, 0.5299517892461805, 0.00113920545553204]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline48 {'type': 'polyline', 'positions': [[0.6874351498626363, 0.08116672264156621, -0.2089673070761061], [1.0914670822166097, -1.1046246506113024, -0.11061845110381607]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline40 {'type': 'polyline', 'positions': [[0.6874351498626363, 0.08116672264156621, -0.2089673070761061], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline56 {'type': 'polyline', 'positions': [[-0.39932648865951187, 0.5299517892461805, 0.00113920545553204], [-1.20854067830814, 0.5320279382329969, 0.049342191353192295]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline53 {'type': 'polyline', 'positions': [[-0.39932648865951187, 0.5299517892461805, 0.00113920545553204], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline54 {'type': 'polyline', 'positions': [[-0.39932648865951187, 0.5299517892461805, 0.00113920545553204], [0.6874351498626363, 0.08116672264156621, -0.2089673070761061]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline51 {'type': 'polyline', 'positions': [[-0.39932648865951187, 0.5299517892461805, 0.00113920545553204], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline65 {'type': 'polyline', 'positions': [[-1.20854067830814, 0.5320279382329969, 0.049342191353192295], [-0.39932648865951187, 0.5299517892461805, 0.00113920545553204]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline67 {'type': 'polyline', 'positions': [[-1.20854067830814, 0.5320279382329969, 0.049342191353192295], [-1.8072684410072672, 0.3630745195013074, -1.0843002884241437]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline61 {'type': 'polyline', 'positions': [[-1.20854067830814, 0.5320279382329969, 0.049342191353192295], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline63 {'type': 'polyline', 'positions': [[-1.20854067830814, 0.5320279382329969, 0.049342191353192295], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline76 {'type': 'polyline', 'positions': [[-1.8072684410072672, 0.3630745195013074, -1.0843002884241437], [-1.20854067830814, 0.5320279382329969, 0.049342191353192295]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline71 {'type': 'polyline', 'positions': [[-1.8072684410072672, 0.3630745195013074, -1.0843002884241437], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline79 {'type': 'polyline', 'positions': [[-1.8072684410072672, 0.3630745195013074, -1.0843002884241437], [-1.4155787828422892, -1.0755001522439929, -1.22531903670753]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline72 {'type': 'polyline', 'positions': [[-1.8072684410072672, 0.3630745195013074, -1.0843002884241437], [-0.7119709852196086, -0.7503663517374011, -1.1731191961618757]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline84 {'type': 'polyline', 'positions': [[1.0914670822166097, -1.1046246506113024, -0.11061845110381607], [0.6874351498626363, 0.08116672264156621, -0.2089673070761061]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline83 {'type': 'polyline', 'positions': [[1.0914670822166097, -1.1046246506113024, -0.11061845110381607], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline80 {'type': 'polyline', 'positions': [[1.0914670822166097, -1.1046246506113024, -0.11061845110381607], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline92 {'type': 'polyline', 'positions': [[-1.4155787828422892, -1.0755001522439929, -1.22531903670753], [-0.7119709852196086, -0.7503663517374011, -1.1731191961618757]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline91 {'type': 'polyline', 'positions': [[-1.4155787828422892, -1.0755001522439929, -1.22531903670753], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline90 {'type': 'polyline', 'positions': [[-1.4155787828422892, -1.0755001522439929, -1.22531903670753], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline97 {'type': 'polyline', 'positions': [[-1.4155787828422892, -1.0755001522439929, -1.22531903670753], [-1.8072684410072672, 0.3630745195013074, -1.0843002884241437]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# Info: Total files 0 | Changed 0 | Failed 0
# Info: Saved "blender_scene.blend"
# Saved blender file to: /local/home/ekoller/visscenegraph/20c993b3-698f-29c5-859c-dca8ddecf220/nodes/blender_scene.blend
#
# Blender quit
#
# ************************************************************************
# Blender instructions
# cd /local/home/ekoller/visscenegraph/20c993b3-698f-29c5-859c-dca8ddecf220/nodes; /local/home/ekoller/visscenegraph/blender-4.1.1-linux-x64/blender --background --python blender_script.py
# ************************************************************************
#
# ************************************************************************
# 1) Start local server:
#     cd /local/home/ekoller/visscenegraph/20c993b3-698f-29c5-859c-dca8ddecf220/pcs_nodes; python -m http.server 8080
# 2) Open in browser:
#     http://localhost:8080
# ************************************************************************
# Blender 4.1.1 (hash e1743a0317bc built 2024-04-15 23:47:45)
# <bpy_struct, Object("Cube") at 0x7f5c6713b708>
# <bpy_struct, Object("Light") at 0x7f5c6713bc08>
# <bpy_struct, Object("Camera") at 0x7f5c6713b208>
# Camera_0 {'type': 'camera', 'position': [-0.5, -2.5, 2.799999952316284], 'look_at': [0.0, 0.0, -0.30000001192092896], 'up': [0.0, 0.0, 1.0], 'focal_length': 28.0, 'animation': False}
# obj_1 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_1.bin'}
# PLY import of 'obj_1.ply' took 0.51 ms
# pcs_obj_1 {'type': 'points', 'visible': True, 'alpha': 0.1, 'shading_type': 1, 'point_size': 50, 'num_points': 2621, 'binary_filename': 'pcs_obj_1.bin'}
# PLY import of 'pcs_obj_1.ply' took 60.51 ms
# obj_2 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_2.bin'}
# PLY import of 'obj_2.ply' took 0.52 ms
# pcs_obj_2 {'type': 'points', 'visible': True, 'alpha': 0.1, 'shading_type': 1, 'point_size': 50, 'num_points': 1429, 'binary_filename': 'pcs_obj_2.bin'}
# PLY import of 'pcs_obj_2.ply' took 31.02 ms
# obj_3 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_3.bin'}
# PLY import of 'obj_3.ply' took 0.49 ms
# pcs_obj_3 {'type': 'points', 'visible': True, 'alpha': 0.1, 'shading_type': 1, 'point_size': 50, 'num_points': 330, 'binary_filename': 'pcs_obj_3.bin'}
# PLY import of 'pcs_obj_3.ply' took 6.33 ms
# obj_4 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_4.bin'}
# PLY import of 'obj_4.ply' took 0.45 ms
# pcs_obj_4 {'type': 'points', 'visible': True, 'alpha': 0.1, 'shading_type': 1, 'point_size': 50, 'num_points': 524, 'binary_filename': 'pcs_obj_4.bin'}
# PLY import of 'pcs_obj_4.ply' took 11.95 ms
# obj_5 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_5.bin'}
# PLY import of 'obj_5.ply' took 0.45 ms
# pcs_obj_5 {'type': 'points', 'visible': True, 'alpha': 0.1, 'shading_type': 1, 'point_size': 50, 'num_points': 1441, 'binary_filename': 'pcs_obj_5.bin'}
# PLY import of 'pcs_obj_5.ply' took 31.64 ms
# obj_6 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_6.bin'}
# PLY import of 'obj_6.ply' took 0.46 ms
# pcs_obj_6 {'type': 'points', 'visible': True, 'alpha': 0.1, 'shading_type': 1, 'point_size': 50, 'num_points': 9009, 'binary_filename': 'pcs_obj_6.bin'}
# PLY import of 'pcs_obj_6.ply' took 283.79 ms
# obj_7 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_7.bin'}
# PLY import of 'obj_7.ply' took 0.56 ms
# pcs_obj_7 {'type': 'points', 'visible': True, 'alpha': 0.1, 'shading_type': 1, 'point_size': 50, 'num_points': 1771, 'binary_filename': 'pcs_obj_7.bin'}
# PLY import of 'pcs_obj_7.ply' took 42.56 ms
# obj_8 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_8.bin'}
# PLY import of 'obj_8.ply' took 0.52 ms
# pcs_obj_8 {'type': 'points', 'visible': True, 'alpha': 0.1, 'shading_type': 1, 'point_size': 50, 'num_points': 248, 'binary_filename': 'pcs_obj_8.bin'}
# PLY import of 'pcs_obj_8.ply' took 5.18 ms
# obj_9 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_9.bin'}
# PLY import of 'obj_9.ply' took 0.55 ms
# pcs_obj_9 {'type': 'points', 'visible': True, 'alpha': 0.1, 'shading_type': 1, 'point_size': 50, 'num_points': 4079, 'binary_filename': 'pcs_obj_9.bin'}
# PLY import of 'pcs_obj_9.ply' took 131.22 ms
# obj_12 {'type': 'points', 'visible': True, 'alpha': 1.0, 'shading_type': 0, 'point_size': 200, 'num_points': 1, 'binary_filename': 'obj_12.bin'}
# PLY import of 'obj_12.ply' took 0.47 ms
# pcs_obj_12 {'type': 'points', 'visible': True, 'alpha': 0.1, 'shading_type': 1, 'point_size': 50, 'num_points': 147, 'binary_filename': 'pcs_obj_12.bin'}
# PLY import of 'pcs_obj_12.ply' took 3.03 ms
# polyline01 {'type': 'polyline', 'positions': [[-0.2764336395121921, -0.4038486696619006, -1.291274437174449], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline02 {'type': 'polyline', 'positions': [[-0.2764336395121921, -0.4038486696619006, -1.291274437174449], [-0.7119709852196086, -0.7503663517374011, -1.1731191961618757]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline03 {'type': 'polyline', 'positions': [[-0.2764336395121921, -0.4038486696619006, -1.291274437174449], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline09 {'type': 'polyline', 'positions': [[-0.2764336395121921, -0.4038486696619006, -1.291274437174449], [-1.4155787828422892, -1.0755001522439929, -1.22531903670753]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline10 {'type': 'polyline', 'positions': [[-0.5594682696319926, -0.3843980051416369, -1.0238404362055158], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline12 {'type': 'polyline', 'positions': [[-0.5594682696319926, -0.3843980051416369, -1.0238404362055158], [-0.7119709852196086, -0.7503663517374011, -1.1731191961618757]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline13 {'type': 'polyline', 'positions': [[-0.5594682696319926, -0.3843980051416369, -1.0238404362055158], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline19 {'type': 'polyline', 'positions': [[-0.5594682696319926, -0.3843980051416369, -1.0238404362055158], [-1.4155787828422892, -1.0755001522439929, -1.22531903670753]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline21 {'type': 'polyline', 'positions': [[-0.7119709852196086, -0.7503663517374011, -1.1731191961618757], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline20 {'type': 'polyline', 'positions': [[-0.7119709852196086, -0.7503663517374011, -1.1731191961618757], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline29 {'type': 'polyline', 'positions': [[-0.7119709852196086, -0.7503663517374011, -1.1731191961618757], [-1.4155787828422892, -1.0755001522439929, -1.22531903670753]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline23 {'type': 'polyline', 'positions': [[-0.7119709852196086, -0.7503663517374011, -1.1731191961618757], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline30 {'type': 'polyline', 'positions': [[0.10622605653034561, -0.08493544830264765, -0.8353701917978621], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline31 {'type': 'polyline', 'positions': [[0.10622605653034561, -0.08493544830264765, -0.8353701917978621], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline34 {'type': 'polyline', 'positions': [[0.10622605653034561, -0.08493544830264765, -0.8353701917978621], [0.6874351498626363, 0.08116672264156621, -0.2089673070761061]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline32 {'type': 'polyline', 'positions': [[0.10622605653034561, -0.08493544830264765, -0.8353701917978621], [-0.7119709852196086, -0.7503663517374011, -1.1731191961618757]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline43 {'type': 'polyline', 'positions': [[0.6874351498626363, 0.08116672264156621, -0.2089673070761061], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline45 {'type': 'polyline', 'positions': [[0.6874351498626363, 0.08116672264156621, -0.2089673070761061], [-0.39932648865951187, 0.5299517892461805, 0.00113920545553204]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline48 {'type': 'polyline', 'positions': [[0.6874351498626363, 0.08116672264156621, -0.2089673070761061], [1.0914670822166097, -1.1046246506113024, -0.11061845110381607]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline40 {'type': 'polyline', 'positions': [[0.6874351498626363, 0.08116672264156621, -0.2089673070761061], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline56 {'type': 'polyline', 'positions': [[-0.39932648865951187, 0.5299517892461805, 0.00113920545553204], [-1.20854067830814, 0.5320279382329969, 0.049342191353192295]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline53 {'type': 'polyline', 'positions': [[-0.39932648865951187, 0.5299517892461805, 0.00113920545553204], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline54 {'type': 'polyline', 'positions': [[-0.39932648865951187, 0.5299517892461805, 0.00113920545553204], [0.6874351498626363, 0.08116672264156621, -0.2089673070761061]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline51 {'type': 'polyline', 'positions': [[-0.39932648865951187, 0.5299517892461805, 0.00113920545553204], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline65 {'type': 'polyline', 'positions': [[-1.20854067830814, 0.5320279382329969, 0.049342191353192295], [-0.39932648865951187, 0.5299517892461805, 0.00113920545553204]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline67 {'type': 'polyline', 'positions': [[-1.20854067830814, 0.5320279382329969, 0.049342191353192295], [-1.8072684410072672, 0.3630745195013074, -1.0843002884241437]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline61 {'type': 'polyline', 'positions': [[-1.20854067830814, 0.5320279382329969, 0.049342191353192295], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline63 {'type': 'polyline', 'positions': [[-1.20854067830814, 0.5320279382329969, 0.049342191353192295], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline76 {'type': 'polyline', 'positions': [[-1.8072684410072672, 0.3630745195013074, -1.0843002884241437], [-1.20854067830814, 0.5320279382329969, 0.049342191353192295]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline71 {'type': 'polyline', 'positions': [[-1.8072684410072672, 0.3630745195013074, -1.0843002884241437], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline79 {'type': 'polyline', 'positions': [[-1.8072684410072672, 0.3630745195013074, -1.0843002884241437], [-1.4155787828422892, -1.0755001522439929, -1.22531903670753]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline72 {'type': 'polyline', 'positions': [[-1.8072684410072672, 0.3630745195013074, -1.0843002884241437], [-0.7119709852196086, -0.7503663517374011, -1.1731191961618757]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline84 {'type': 'polyline', 'positions': [[1.0914670822166097, -1.1046246506113024, -0.11061845110381607], [0.6874351498626363, 0.08116672264156621, -0.2089673070761061]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline83 {'type': 'polyline', 'positions': [[1.0914670822166097, -1.1046246506113024, -0.11061845110381607], [0.10622605653034561, -0.08493544830264765, -0.8353701917978621]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline80 {'type': 'polyline', 'positions': [[1.0914670822166097, -1.1046246506113024, -0.11061845110381607], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline92 {'type': 'polyline', 'positions': [[-1.4155787828422892, -1.0755001522439929, -1.22531903670753], [-0.7119709852196086, -0.7503663517374011, -1.1731191961618757]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline91 {'type': 'polyline', 'positions': [[-1.4155787828422892, -1.0755001522439929, -1.22531903670753], [-0.5594682696319926, -0.3843980051416369, -1.0238404362055158]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline90 {'type': 'polyline', 'positions': [[-1.4155787828422892, -1.0755001522439929, -1.22531903670753], [-0.2764336395121921, -0.4038486696619006, -1.291274437174449]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# polyline97 {'type': 'polyline', 'positions': [[-1.4155787828422892, -1.0755001522439929, -1.22531903670753], [-1.8072684410072672, 0.3630745195013074, -1.0843002884241437]], 'color': [250.0, 250.0, 250.0], 'alpha': 1.0, 'edge_width': 0.02, 'visible': True}
# Info: Total files 0 | Changed 0 | Failed 0
# Info: Saved "blender_scene.blend"
# Saved blender file to: /local/home/ekoller/visscenegraph/20c993b3-698f-29c5-859c-dca8ddecf220/pcs_nodes/blender_scene.blend
#
# Blender quit
#
# ************************************************************************
# Blender instructions
# cd /local/home/ekoller/visscenegraph/20c993b3-698f-29c5-859c-dca8ddecf220/pcs_nodes; /local/home/ekoller/visscenegraph/blender-4.1.1-linux-x64/blender --background --python blender_script.py
# ************************************************************************
